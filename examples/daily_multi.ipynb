# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

import gym
import gym_anytrading
import quantstats as qs

import matplotlib.pyplot as plt

from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import DummyVecEnv

# %% [markdown]
# ### Create Env

# %%
selection = 1
tickers = ['NESZ', 'CIMB', 'MAY', 'KLK']

df = {}
for ticker in tickers:
    df[ticker] = pd.read_csv('day_data/{} MK Equity.csv'.format(ticker),parse_dates=True, index_col='Dates')

print(len(df))
      
window_size = 10
start_index = window_size
end_index = len(df[tickers[selection]])

env_maker_train = lambda: gym.make(
    'daily-v0',
    df = df, 
    window_size = window_size,
    frame_bound = (start_index, end_index//2),
    bankroll=100000.
)

env_train = DummyVecEnv([env_maker_train])

env_maker_val = lambda: gym.make(
    'daily-v0',
    df = df,
    window_size = window_size,
    frame_bound = (end_index//2, end_index),
    bankroll=100000.
)

env_val = DummyVecEnv([env_maker_val])
# Out:
# 4
# NESZ
# CIMB
# MAY
# KLK
# Continuous action space
# NESZ
# CIMB
# MAY
# KLK
# Continuous action space

# %% [markdown]
# ### Train Env

# %%
#policy_kwargs = dict(net_arch=[64, 'lstm', dict(vf=[128, 128, 128], pi=[64, 64])])
model = A2C('MlpPolicy', env_train, verbose=1)# , policy_kwargs=policy_kwargs)
model.learn(total_timesteps=1000)
# Out:
# Using cpu device
# -------------------------------------
# | time/                 |           |
# |    fps                | 2674      |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -7.04     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 8.24e+03  |
# |    std                | 0.989     |
# |    value_loss         | 2.58e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2559      |
# |    iterations         | 200       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -7.01     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -3.39e+03 |
# |    std                | 0.982     |
# |    value_loss         | 4.41e+05  |
# -------------------------------------

# %% [markdown]
# ### Custom Model

# %% [markdown]
# ### Test Env

# %%
env = env_maker_train() #env_maker_val()
observation = env.reset()
print(observation[np.newaxis, ...])

c = 0
while True:
    c+=1
    #observation = observation[np.newaxis, ...]

    # action = env.action_space.sample()
    action, _states = model.predict(observation)
   
    #print(action.shape)
    observation, reward, done, info = env.step(action)

    #env.render()
    if done:
        print("info:", info)
        print("iterations", c)
        break
# Out:
# NESZ
# CIMB
# MAY
# KLK
# Continuous action space
# [[[[ 1.700e+01  0.000e+00]
#    [ 2.373e+00  0.000e+00]
#    [ 6.658e+00  0.000e+00]
#    [ 3.500e+00  0.000e+00]]
#
#   [[ 1.700e+01  0.000e+00]
#    [ 2.360e+00 -1.300e-02]
#    [ 6.706e+00  4.800e-02]
#    [ 3.533e+00  3.300e-02]]
#
#   [[ 1.690e+01 -1.000e-01]
#    [ 2.348e+00 -1.200e-02]
#    [ 6.658e+00 -4.800e-02]
#    [ 3.500e+00 -3.300e-02]]
#
#   [[ 1.680e+01 -1.000e-01]
#    [ 2.323e+00 -2.500e-02]
#    [ 6.610e+00 -4.800e-02]
#    [ 3.467e+00 -3.300e-02]]
#
#   [[ 1.680e+01  0.000e+00]
#    [ 2.323e+00  0.000e+00]
#    [ 6.610e+00  0.000e+00]
#    [ 3.467e+00  0.000e+00]]
#
#   [[ 1.680e+01  0.000e+00]
#    [ 2.323e+00  0.000e+00]
#    [ 6.610e+00  0.000e+00]
#    [ 3.467e+00  0.000e+00]]
#
#   [[ 1.690e+01  1.000e-01]
#    [ 2.434e+00  1.110e-01]
#    [ 6.801e+00  1.910e-01]
#    [ 3.433e+00 -3.400e-02]]
#
#   [[ 1.690e+01  0.000e+00]
#    [ 2.694e+00  2.600e-01]
#    [ 7.089e+00  2.880e-01]
#    [ 3.333e+00 -1.000e-01]]
#
#   [[ 1.690e+01  0.000e+00]
#    [ 2.694e+00  0.000e+00]
#    [ 7.568e+00  4.790e-01]
#    [ 3.467e+00  1.340e-01]]
#
#   [[ 1.730e+01  4.000e-01]
#    [ 2.768e+00  7.400e-02]
#    [ 8.095e+00  5.270e-01]
#    [ 3.567e+00  1.000e-01]]]]
# info: {'total_reward': 159580.06599999988, 'total_profit': 159580.06599999988, 'position': array([1.0817e+01, 0.0000e+00, 1.2607e+04, 1.7625e+04, 0.0000e+00]), 'delta': array([-5.2260e+00,  0.0000e+00,  1.2258e+04,  1.5780e+03, -6.3810e+03]), 'net_worth': 259580.06600000005}
# iterations 2801

# %% [markdown]
# ### Plot Results

# %%
plt.figure(figsize=(16, 6))
env.render_all()
plt.show()

# %%
plt.figure(figsize=(16, 6))
env.render_net_worth()
plt.show()

# %%
print(np.array(env.history['position'])[:,0].mean())
print(np.array(env.history['net_worth']).mean())
#np.array(env.history['position'])[:,0].min()
# Out:
# 34780.224205283834
# 128777.87083434488

# %%
class CustomModel:
    # Buy and Hold
    def __init__(self, env, strategy='buy and hold'):
        self.env = env        
        strategies = ['buy and hold', 'overnight', 'intraday', 'random walk']
        self.strategy = strategies.index(strategy)
    def learn(self, total_timesteps=1000):
        pass
    def predict(self, observation):
        if self.strategy == 0:
            return 1, None
        elif self.strategy == 1:
            pass 
        elif self.strategy == 2:
            pass
        elif self.strategy == 3:
            pass
    

# model = CustomModel(env)

# %% [markdown]
# ### Analysis Using `quantstats`

# %%
qs.extend_pandas()

net_worth = pd.Series(np.array(env.history['net_worth']), index=df['NESZ'].index[start_index+1:end_index//2] )#df['CIMB'].index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
#qs.reports.html(returns, output=True, download_filename='custom_quantstats.html')
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2000-01-19
# End Period                 2010-10-12
# Risk-Free Rate             0.0%
# Time in Market             79.0%
#
# Cumulative Return          154.24%
# CAGR﹪                     9.08%
#
# Sharpe                     0.53
# Smart Sharpe               0.53
# Sortino                    0.77
# Smart Sortino              0.77
# Sortino/√2                 0.55
# Smart Sortino/√2           0.54
# Omega                      1.12
#
# Max Drawdown               -40.14%
# Longest DD Days            1470
# Volatility (ann.)          19.19%
# Calmar                     0.23
# Skew                       -0.45
# Kurtosis                   15.71
#
# Expected Daily %           0.03%
# Expected Monthly %         0.72%
# Expected Yearly %          8.85%
# Kelly Criterion            5.45%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -1.95%
# Expected Shortfall (cVaR)  -1.95%
#
# Gain/Pain Ratio            0.12
# Gain/Pain (1M)             0.55
#
# Payoff Ratio               1.03
# Profit Factor              1.12
# Common Sense Ratio         1.19
# CPC Index                  0.6
# Tail Ratio                 1.07
# Outlier Win Ratio          5.82
# Outlier Loss Ratio         3.35
#
# MTD                        4.4%
# 3M                         23.31%
# 6M                         22.16%
# YTD                        26.7%
# 1Y                         19.29%
# 3Y (ann.)                  7.5%
# 5Y (ann.)                  14.65%
# 10Y (ann.)                 11.7%
# All-time (ann.)            9.08%
#
# Best Day                   9.34%
# Worst Day                  -14.4%
# Best Month                 26.46%
# Worst Month                -15.08%
# Best Year                  38.11%
# Worst Year                 -25.71%
#
# Avg. Drawdown              -4.49%
# Avg. Drawdown Days         72
# Recovery Factor            3.84
# Ulcer Index                0.17
# Serenity Index             0.36
#
# Avg. Up Month              4.42%
# Avg. Down Month            -3.68%
# Win Days %                 52.06%
# Win Month %                56.15%
# Win Quarter %              59.09%
# Win Year %                 72.73%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2000-02-16  2001-04-10  2004-02-25  1470    -40.144398        -39.043615
# 2  2007-10-30  2008-10-28  2009-07-17   626    -38.533321        -36.886374
# 3  2009-10-06  2010-02-11  2010-10-06   365    -19.985294        -19.969520
# 4  2004-12-08  2005-06-01  2005-12-09   366    -16.848410        -16.025153
# 5  2007-04-19  2007-08-17  2007-10-26   190    -14.998473        -11.371317
# <h4>Strategy Visualization</h4>
